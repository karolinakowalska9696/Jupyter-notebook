# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Karolina Kowalska**

# %% [markdown]
# Scientist

# %% [markdown]
# *I am interested in data science because it accelerates new adnancements in research. Therefore it is very useful in my working environment.*

# %% [markdown]
# ### My code will display a phrase "Shopping list" ###

# %%
print('Shopping list')
# Out:
# Shopping list

# %% [markdown]
# - bread

# %% [markdown]
#  - juice

# %% [markdown]
#  1. apples

# %% [markdown]
#  2. milk

# %% [markdown]
# ![00_groceryshopping_This-is-the-Absolute-Worst-Day-to-Shop-for-Your-Thanksgiving-Groceries_299082896_wavebreakmedia.jpg](attachment:d174c2a3-e5a3-4600-84e1-98d9b9d2c653.jpg)

# %% [markdown]
# >The end of the notebook
